# %%
import glob
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import math
import csv
import seaborn as sns

# %%
sujeto_1= pd.read_csv('df_sujeto_1_ojos_cerrados.csv') 
sujeto_2= pd.read_csv('df_sujeto_2_ojos_cerrados.csv', sep=';') 
sujeto_3= pd.read_csv('df_sujeto_3_ojos_cerrados.csv', sep=';') 
sujeto_4= pd.read_csv('df_sujeto_4_ojos_cerrados.csv') 
sujeto_5= pd.read_csv('df_sujeto_5_ojos_cerrados.csv', sep=';') 
sujeto_5
# Out:
#       N_AF3      N_F7      N_F3     N_FC5      N_T7      N_P7      N_O1  \
# 0  1.859571  1.678915  2.372838  2.538295  2.484992  3.897848  1.158750
# 1  1.709498  1.709498  1.470590  2.675550  2.265118  3.375363  0.388507
# 2  1.854088  1.854088  1.639717  2.784015  2.917669  4.211183  0.438055
# 3  2.014467  1.690110  3.359667  2.579126  2.877502  3.433773  0.940291
# 4  2.177130  2.177130  1.882663  1.882663  3.368917  1.829542  0.499608
#
#        N_O2      N_P8      N_T8  ...      N_F8     N_AF4   MED_CAN   STD_EEG  \
# 0  0.295753  0.515397  0.686940  ...  0.741749  1.468327  4.950797  0.956024
# 1  1.265071  0.248030  0.510792  ...  1.823816  0.809255  3.993289  1.023089
# 2  1.096659  0.235648  0.463155  ...  1.900464  0.958561  6.471018  1.246475
# 3  0.210434  0.540336  0.897433  ...  0.954420  1.588493  5.530989  1.008264
# 4  1.468155  0.256990  0.488056  ...  1.888007  0.809216  6.466072  1.201547
#
#    MAX_EST  STD_LATERAL  STD_ANTERO  MED_LATERAL  MED_ANTERO  TARGET
# ...

# %%
#Dejar canales de EEG
sujeto_1EEG_ch=sujeto_1.drop(["MED_CAN",	"STD_EEG",	"MAX_EST", "STD_LATERAL",	"STD_ANTERO",	"MED_LATERAL",	"MED_ANTERO",	"TARGET"],axis=1)
sujeto_2EEG_ch=sujeto_2.drop(["MED_CAN",	"STD_EEG",	"MAX_EST", "STD_LATERAL",	"STD_ANTERO",	"MED_LATERAL",	"MED_ANTERO",	"TARGET"],axis=1)
sujeto_3EEG_ch=sujeto_3.drop(["MED_CAN",	"STD_EEG",	"MAX_EST", "STD_LATERAL",	"STD_ANTERO",	"MED_LATERAL",	"MED_ANTERO",	"TARGET"],axis=1)
sujeto_4EEG_ch=sujeto_4.drop(["MED_CAN",	"STD_EEG",	"MAX_EST", "STD_LATERAL",	"STD_ANTERO",	"MED_LATERAL",	"MED_ANTERO",	"TARGET"],axis=1)
sujeto_5EEG_ch=sujeto_5.drop(["MED_CAN",	"STD_EEG",	"MAX_EST", "STD_LATERAL",	"STD_ANTERO",	"MED_LATERAL",	"MED_ANTERO",	"TARGET"],axis=1)
sujeto_1EEG_ch
# Out:
#       N_AF3      N_F7      N_F3     N_FC5      N_T7      N_P7      N_O1  \
# 0  1.070905  1.253067  1.213321  1.956310  3.255310  2.400594  0.673791
# 1  0.975683  1.210489  1.134753  1.853488  3.415301  2.267112  0.682204
# 2  1.133688  1.740747  2.206395  2.829631  2.137994  1.381230  0.828468
# 3  1.356937  1.133883  1.744424  3.375840  1.730380  0.426943  0.811179
# 4  1.360131  1.191385  1.642549  2.231184  1.589382  0.742116  0.927182
#
#        N_O2      N_P8      N_T8     N_FC6      N_F4      N_F8     N_AF4
# 0  0.821157  0.848538  0.634925  1.172654  1.076600  0.628966  0.723529
# 1  0.793766  0.822566  0.751900  1.128115  1.210994  0.656138  0.672630
# 2  0.710207  0.539554  1.374861  0.961031  0.646200  0.724315  0.724315
# 3  1.545285  1.022212  1.154342  1.132157  0.785892  0.737647  0.737647
# 4  0.777011  0.647582  1.254925  1.140903  0.704967  0.836768  0.836768

# %%
####CANALES DE EEG: TOMA COMPLETA 
cn1=pd.concat([sujeto_1EEG_ch, sujeto_2EEG_ch, sujeto_3EEG_ch, sujeto_4EEG_ch, sujeto_5EEG_ch])

#cn1=sujeto_1EEG_ch.columns
sujeto_1_melted=sujeto_3EEG_ch.melt(value_vars=cn1, value_name='Voltaje normalizado', var_name='Canales de EEG')
sns.boxplot( x='Canales de EEG',y='Voltaje normalizado', data=sujeto_1_melted).set(title='Canales de electroencefalografia: Toma completa - ojos cerrados',ylabel='PSD normalizada',xlabel='Canales de EEG')

sns.set(rc={'figure.figsize':(12,8)})
plt.tight_layout()
plt.show()

# %%
cn1.describe()
# Out:
#            N_AF3       N_F7       N_F3      N_FC5       N_T7       N_P7  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    1.009384   1.005919   1.507112   1.658799   2.535505   2.961345
# std     0.360605   0.466564   0.561038   0.644114   1.864705   1.582056
# min     0.348741   0.367423   0.468227   0.721225   0.300352   0.961096
# 25%     0.767093   0.682870   1.263836   1.324673   1.552330   2.072601
# 50%     1.072163   0.955010   1.423853   1.558888   2.158239   2.430437
# 75%     1.256549   1.197533   1.612725   1.836464   3.110845   3.262899
# max     1.625949   2.555514   3.211585   3.637366   8.800378   6.598567
#
#             N_O1       N_O2       N_P8       N_T8      N_FC6       N_F4  \
# count  25.000000  25.000000  25.000000  25.000000  25.000000  25.000000
# mean    1.978907   1.205930   0.942073   1.041331   1.168479   1.019194
# std     1.487993   0.712268   0.409867   0.415490   0.439116   0.378679
# ...

# %%
data1=sujeto_1EEG_ch.assign(Sujeto=1)
data2=sujeto_2EEG_ch.assign(Sujeto=2)
data3=sujeto_1EEG_ch.assign(Sujeto=3)
data4=sujeto_2EEG_ch.assign(Sujeto=4)
data5=sujeto_1EEG_ch.assign(Sujeto=5)

cdf=pd.concat([data1,data2,data3,data4,data5])
mdf=pd.melt(cdf, id_vars='Sujeto', var_name=['Canales'])

ax = sns.boxplot(x="Sujeto", y="value", hue="Canales", data=mdf).set(title='Boxplot dividido por sujetos: Toma de datos con ojos abiertos',ylabel='PSD normalizada',xlabel='Canales de EEG')
 
sns.set(rc={'figure.figsize':(10,7)})   
plt.tight_layout()
plt.show()

# %%
af3_1=sujeto_1EEG_ch['N_AF3']
af3_2=sujeto_2EEG_ch['N_AF3']
af3_3=sujeto_3EEG_ch['N_AF3']
af3_4=sujeto_4EEG_ch['N_AF3']
af3_5=sujeto_5EEG_ch['N_AF3']

canal_AF3=pd.concat([af3_1,af3_2, af3_3, af3_4, af3_5],axis=1)
canal_AF3.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_AF3x=canal_AF3.assign(Canal='AF3')



#-----------------------------------------------------------------------------------------

f7_1=sujeto_1EEG_ch['N_F7']
f7_2=sujeto_2EEG_ch['N_F7']
f7_3=sujeto_3EEG_ch['N_F7']
f7_4=sujeto_4EEG_ch['N_F7']
f7_5=sujeto_5EEG_ch['N_F7']

canal_F7=pd.concat([f7_1,f7_2,f7_3,f7_4,f7_5],axis=1)
canal_F7.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_F7x=canal_F7.assign(Canal='F7')
#-------------------------------------------------------------------------------------------
f3_1=sujeto_1EEG_ch['N_F3']
f3_2=sujeto_2EEG_ch['N_F3']
f3_3=sujeto_3EEG_ch['N_F3']
f3_4=sujeto_4EEG_ch['N_F3']
f3_5=sujeto_5EEG_ch['N_F3']

canal_F3=pd.concat([f3_1,f3_2,f3_3,f3_4,f3_5],axis=1)
canal_F3.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_F3x=canal_F3.assign(Canal='F3')
#--------------------------------------------------------------------------------------------
fc5_1=sujeto_1EEG_ch['N_FC5']
fc5_2=sujeto_2EEG_ch['N_FC5']
fc5_3=sujeto_3EEG_ch['N_FC5']
fc5_4=sujeto_4EEG_ch['N_FC5']
fc5_5=sujeto_5EEG_ch['N_FC5']

canal_FC5=pd.concat([fc5_1,fc5_2,fc5_3,fc5_4,fc5_5],axis=1)
canal_FC5.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_FC5x=canal_FC5.assign(Canal='FC5')
#---------------------------------------------------------------------------------
t7_1=sujeto_1EEG_ch['N_T7']
t7_2=sujeto_2EEG_ch['N_T7']
t7_3=sujeto_3EEG_ch['N_T7']
t7_4=sujeto_4EEG_ch['N_T7']
t7_5=sujeto_5EEG_ch['N_T7']

canal_T7=pd.concat([t7_1,t7_2,t7_3,t7_4,t7_5],axis=1)
canal_T7.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_T7x=canal_T7.assign(Canal='T7')
#-------------------------------------------------------------------------------------------
p7_1=sujeto_1EEG_ch['N_P7']
p7_2=sujeto_2EEG_ch['N_P7']
p7_3=sujeto_3EEG_ch['N_P7']
p7_4=sujeto_4EEG_ch['N_P7']
p7_5=sujeto_5EEG_ch['N_P7']

canal_P7=pd.concat([p7_1,p7_2,p7_3,p7_4,p7_5],axis=1)
canal_P7.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_P7x=canal_P7.assign(Canal='P7')
#------------------------------------------------------------------------------------------------
o1_1=sujeto_1EEG_ch['N_O1']
o1_2=sujeto_2EEG_ch['N_O1']
o1_3=sujeto_3EEG_ch['N_O1']
o1_4=sujeto_4EEG_ch['N_O1']
o1_5=sujeto_5EEG_ch['N_O1']

canal_O1=pd.concat([o1_1,o1_2,o1_3,o1_4,o1_5],axis=1)
canal_O1.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_O1x=canal_O1.assign(Canal='O1')

#--------------------------------------------------------------------------------------------
o2_1=sujeto_1EEG_ch['N_O2']
o2_2=sujeto_2EEG_ch['N_O2']
o2_3=sujeto_3EEG_ch['N_O2']
o2_4=sujeto_4EEG_ch['N_O2']
o2_5=sujeto_5EEG_ch['N_O2']

canal_O2=pd.concat([o2_1,o2_2,o2_3,o2_4,o2_5],axis=1)
canal_O2.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_O2x=canal_O2.assign(Canal='O2')
#------------------------------------------------------------------------------------------------
p8_1=sujeto_1EEG_ch['N_P8']
p8_2=sujeto_2EEG_ch['N_P8']
p8_3=sujeto_3EEG_ch['N_P8']
p8_4=sujeto_4EEG_ch['N_P8']
p8_5=sujeto_5EEG_ch['N_P8']

canal_P8=pd.concat([p8_1,p8_2,p8_3,p8_4,p8_5],axis=1)
canal_P8.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_P8x=canal_P8.assign(Canal='P8')
#------------------------------------------------------------------------------------------------
t8_1=sujeto_1EEG_ch['N_T8']
t8_2=sujeto_2EEG_ch['N_T8']
t8_3=sujeto_3EEG_ch['N_T8']
t8_4=sujeto_4EEG_ch['N_T8']
t8_5=sujeto_5EEG_ch['N_T8']

canal_T8=pd.concat([t8_1,t8_2,t8_3,t8_4,t8_5],axis=1)
canal_T8.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_T8x=canal_T8.assign(Canal='T8')
#---------------------------------------------------------------------------------------------------------
fc6_1=sujeto_1EEG_ch['N_FC6']
fc6_2=sujeto_2EEG_ch['N_FC6']
fc6_3=sujeto_3EEG_ch['N_FC6']
fc6_4=sujeto_4EEG_ch['N_FC6']
fc6_5=sujeto_5EEG_ch['N_FC6']

canal_FC6=pd.concat([fc6_1,fc6_2,fc6_3, fc6_4,fc6_5],axis=1)
canal_FC6.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_FC6x=canal_FC6.assign(Canal='FC6')
#---------------------------------------------------------------------------------------------------------------
f4_1=sujeto_1EEG_ch['N_F4']
f4_2=sujeto_2EEG_ch['N_F4']
f4_3=sujeto_3EEG_ch['N_F4']
f4_4=sujeto_4EEG_ch['N_F4']
f4_5=sujeto_5EEG_ch['N_F4']

canal_F4=pd.concat([f4_1,f4_2,f4_3,f4_4,f4_5],axis=1)
canal_F4.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_F4x=canal_F4.assign(Canal='F4')
#------------------------------------------------------------------------------------------------------------
f8_1=sujeto_1EEG_ch['N_F8']
f8_2=sujeto_2EEG_ch['N_F8']
f8_3=sujeto_3EEG_ch['N_F8']
f8_4=sujeto_4EEG_ch['N_F8']
f8_5=sujeto_5EEG_ch['N_F8']

canal_F8=pd.concat([f8_1,f8_2,f8_3,f8_4,f8_5],axis=1)
canal_F8.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_F8x=canal_F8.assign(Canal='F8')
#-----------------------------------------------------------------------------------------------------------------
af4_1=sujeto_1EEG_ch['N_AF4']
af4_2=sujeto_2EEG_ch['N_AF4']
af4_3=sujeto_3EEG_ch['N_AF4']
af4_4=sujeto_4EEG_ch['N_AF4']
af4_5=sujeto_5EEG_ch['N_AF4']

canal_AF4=pd.concat([af4_1,af4_2,af4_3,af4_4,af4_5],axis=1)
canal_AF4.columns = ['Sujeto 1','Sujeto 2','Sujeto 3', 'Sujeto 4', 'Sujeto 5'] 
canal_AF4x=canal_AF4.assign(Canal='AF4')
#------------------------------------------------------------------------------------------------------------------
cdf = pd.concat([canal_F7x, canal_AF3x, canal_F3x, canal_FC5x, canal_T7x, canal_P7x, canal_O1x, canal_O2x, canal_P8x, canal_T8x, canal_FC6x, canal_F4x, canal_F8x, canal_AF4x])
#cdf

# %%
mdf=pd.melt(cdf, id_vars='Canal', var_name=['Canales'])

ax = sns.boxplot(x="Canal", y="value", hue="Canales", data=mdf).set(title='Canales de electroencefalografia (por sujeto): Toma de datos con ojos cerrados',ylabel='PSD normalizada',xlabel='Canales de EEG')
sns.set(rc={'figure.figsize':(14,9)})   
plt.tight_layout()
plt.show()

# %%
sujeto_1EEG_ch= pd.read_csv('df_sujeto_5_ojos_abiertos.csv') 
sujeto_2EEG_ch= pd.read_csv('df_sujeto_5_ojos_cerrados.csv',sep=';') 
sujeto_2EEG_ch
# Out:
#       N_AF3      N_F7      N_F3     N_FC5      N_T7      N_P7      N_O1  \
# 0  1.859571  1.678915  2.372838  2.538295  2.484992  3.897848  1.158750
# 1  1.709498  1.709498  1.470590  2.675550  2.265118  3.375363  0.388507
# 2  1.854088  1.854088  1.639717  2.784015  2.917669  4.211183  0.438055
# 3  2.014467  1.690110  3.359667  2.579126  2.877502  3.433773  0.940291
# 4  2.177130  2.177130  1.882663  1.882663  3.368917  1.829542  0.499608
#
#        N_O2      N_P8      N_T8  ...      N_F8     N_AF4   MED_CAN   STD_EEG  \
# 0  0.295753  0.515397  0.686940  ...  0.741749  1.468327  4.950797  0.956024
# 1  1.265071  0.248030  0.510792  ...  1.823816  0.809255  3.993289  1.023089
# 2  1.096659  0.235648  0.463155  ...  1.900464  0.958561  6.471018  1.246475
# 3  0.210434  0.540336  0.897433  ...  0.954420  1.588493  5.530989  1.008264
# 4  1.468155  0.256990  0.488056  ...  1.888007  0.809216  6.466072  1.201547
#
#    MAX_EST  STD_LATERAL  STD_ANTERO  MED_LATERAL  MED_ANTERO  TARGET
# ...

# %%
#sujeto_1EEG_ch=sujeto_1.drop(["MED_CAN",	"STD_EEG",	"MAX_EST", "STD_LATERAL",	"STD_ANTERO",	"MED_LATERAL",	"MED_ANTERO",	"TARGET"],axis=1)
#sujeto_2EEG_ch=sujeto_2.drop(["MED_CAN",	"STD_EEG",	"MAX_EST", "STD_LATERAL",	"STD_ANTERO",	"MED_LATERAL",	"MED_ANTERO",	"TARGET"],axis=1, sep=';')


#---------------------------------------------------------------------------------------------------------------------------------------------


af3_1=sujeto_1EEG_ch['N_AF3']
af3_2=sujeto_2EEG_ch['N_AF3']


canal_AF3=pd.concat([af3_1,af3_2],axis=1)
canal_AF3.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_AF3x=canal_AF3.assign(Canal='AF3')



#-----------------------------------------------------------------------------------------

f7_1=sujeto_1EEG_ch['N_F7']
f7_2=sujeto_2EEG_ch['N_F7']


canal_F7=pd.concat([f7_1,f7_2],axis=1)
canal_F7.columns = ['Ojos Abiertos','Ojos Cerrados']
canal_F7x=canal_F7.assign(Canal='F7')
#-------------------------------------------------------------------------------------------
f3_1=sujeto_1EEG_ch['N_F3']
f3_2=sujeto_2EEG_ch['N_F3']


canal_F3=pd.concat([f3_1,f3_2],axis=1)
canal_F3.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_F3x=canal_F3.assign(Canal='F3')
#--------------------------------------------------------------------------------------------
fc5_1=sujeto_1EEG_ch['N_FC5']
fc5_2=sujeto_2EEG_ch['N_FC5']


canal_FC5=pd.concat([fc5_1,fc5_2],axis=1)
canal_FC5.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_FC5x=canal_FC5.assign(Canal='FC5')
#---------------------------------------------------------------------------------
t7_1=sujeto_1EEG_ch['N_T7']
t7_2=sujeto_2EEG_ch['N_T7']

canal_T7=pd.concat([t7_1,t7_2],axis=1)
canal_T7.columns = ['Ojos Abiertos','Ojos Cerrados']
canal_T7x=canal_T7.assign(Canal='T7')
#-------------------------------------------------------------------------------------------
p7_1=sujeto_1EEG_ch['N_P7']
p7_2=sujeto_2EEG_ch['N_P7']


canal_P7=pd.concat([p7_1,p7_2],axis=1)
canal_P7.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_P7x=canal_P7.assign(Canal='P7')
#------------------------------------------------------------------------------------------------
o1_1=sujeto_1EEG_ch['N_O1']
o1_2=sujeto_2EEG_ch['N_O1']


canal_O1=pd.concat([o1_1,o1_2],axis=1)
canal_O1.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_O1x=canal_O1.assign(Canal='O1')

#--------------------------------------------------------------------------------------------
o2_1=sujeto_1EEG_ch['N_O2']
o2_2=sujeto_2EEG_ch['N_O2']


canal_O2=pd.concat([o2_1,o2_2],axis=1)
canal_O2.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_O2x=canal_O2.assign(Canal='O2')
#------------------------------------------------------------------------------------------------
p8_1=sujeto_1EEG_ch['N_P8']
p8_2=sujeto_2EEG_ch['N_P8']


canal_P8=pd.concat([p8_1,p8_2],axis=1)
canal_P8.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_P8x=canal_P8.assign(Canal='P8')
#------------------------------------------------------------------------------------------------
t8_1=sujeto_1EEG_ch['N_T8']
t8_2=sujeto_2EEG_ch['N_T8']


canal_T8=pd.concat([t8_1,t8_2],axis=1)
canal_T8.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_T8x=canal_T8.assign(Canal='T8')
#---------------------------------------------------------------------------------------------------------
fc6_1=sujeto_1EEG_ch['N_FC6']
fc6_2=sujeto_2EEG_ch['N_FC6']


canal_FC6=pd.concat([fc6_1,fc6_2],axis=1)
canal_FC6.columns = ['Ojos Abiertos','Ojos Cerrados']
canal_FC6x=canal_FC6.assign(Canal='FC6')
#---------------------------------------------------------------------------------------------------------------
f4_1=sujeto_1EEG_ch['N_F4']
f4_2=sujeto_2EEG_ch['N_F4']


canal_F4=pd.concat([f4_1,f4_2],axis=1)
canal_F4.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_F4x=canal_F4.assign(Canal='F4')
#------------------------------------------------------------------------------------------------------------
f8_1=sujeto_1EEG_ch['N_F8']
f8_2=sujeto_2EEG_ch['N_F8']


canal_F8=pd.concat([f8_1,f8_2],axis=1)
canal_F8.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_F8x=canal_F8.assign(Canal='F8')
#-----------------------------------------------------------------------------------------------------------------
af4_1=sujeto_1EEG_ch['N_AF4']
af4_2=sujeto_2EEG_ch['N_AF4']


canal_AF4=pd.concat([af4_1,af4_2],axis=1)
canal_AF4.columns = ['Ojos Abiertos','Ojos Cerrados'] 
canal_AF4x=canal_AF4.assign(Canal='AF4')
#------------------------------------------------------------------------------------------------------------------
cdf = pd.concat([canal_F7x, canal_AF3x, canal_F3x, canal_FC5x, canal_T7x, canal_P7x, canal_O1x, canal_O2x, canal_P8x, canal_T8x, canal_FC6x, canal_F4x, canal_F8x, canal_AF4x])
#cdf

# %%
mdf=pd.melt(cdf, id_vars='Canal', var_name=['Canales'])

ax = sns.boxplot(x="Canal", y="value", hue="Canales", data=mdf).set(title='Sujeto 5: ',ylabel='PSD normalizada',xlabel='Canales de EEG')
sns.set(rc={'figure.figsize':(14,7)})   
plt.tight_layout()
plt.show()
